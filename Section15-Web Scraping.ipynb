# %% [markdown]
# # Web Scraping

# %% [markdown]
# #### rules of webscraping
#
# 1. Get permission before scraping -- IP address blockeD?!
#    some sites block scraping software
#    Check webscraping LAWS?!
#
# #### limitations of webscraping
#
# 2. Websites are unique -- web scraping scripts are unique to websites
#
#
# #### basic HTML and CSS
#
# 3. Frontend of a website: HTML + CSS + JS

# %%
import requests

# %%
import bs4

# %% [markdown]
# ### Grab Page TItle

# %%
result = requests.get("http://www.example.com")

# %%
type(result)
# Out:
# requests.models.Response

# %%
result.text ## return UNPARSED text in response object
# Out:
# '<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n   
# ...

# %%
## use beautiful soup -- import bs4

# %%
soup = bs4.BeautifulSoup(result.text, 'lxml') ## formats unparesed text oobjects

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Example Domain</title>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#     </style>
# </head>
# <body>
# <div>
# ...

# %%
soup.select('title') ## select elements  -- returns a list of objects
# Out:
# [<title>Example Domain</title>]

# %%
soup.select('p') ## lets grab just the items of the text
# Out:
# [<p>This domain is for use in illustrative examples in documents. You may use this
#      domain in literature without prior coordination or asking for permission.</p>,
#  <p><a href="https://www.iana.org/domains/example">More information...</a></p>]

# %%
soup.select('title')[0] ## selects list element WITH html <tags>
# Out:
# <title>Example Domain</title>

# %%
type(soup.select('title')[0]) ## returns a beautiful soup class: Tag
# Out:
# bs4.element.Tag

# %%
soup.select('title')[0].getText()
# Out:
# 'Example Domain'

# %%
type(soup.select('title')[0].getText())  ## get text returns string class
# Out:
# str

# %% [markdown]
# **soup.select('div')**   ---    All elements with 'div' tag
#
# **soup.select('#some_id')**  ---   Elements containing id = 'some_id'
#
# **soup.select('.some_class')**    ---   Elements containing class = 'some_class'
#
# **soup.select('div span')**     ---   Any elements named span within a div element
#
# **soup.select('div > span')**   --- Any elements anmed span directly within a div element with nothing between

# %%
## grace hopper - wikipedia scrap

# %%
res = requests.get('https://en.wikipedia.org/wiki/Grace_Hopper') ## get url

# %%
soup = bs4.BeautifulSoup(res.text, 'lxml')

# %%
soup ## entire page formatted
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Grace Hopper - Wikipedia</title>
# ...

# %%
soup.select('.toctext') ## pass in class name we searching for
# Out:
# [<span class="toctext">Early life and education</span>,
#  <span class="toctext">Career</span>,
#  <span class="toctext">World War II</span>,
#  <span class="toctext">UNIVAC</span>,
#  <span class="toctext">COBOL</span>,
#  <span class="toctext">Standards</span>,
#  <span class="toctext">Retirement</span>,
#  <span class="toctext">Post-retirement</span>,
#  <span class="toctext">Anecdotes</span>,
#  <span class="toctext">Death</span>,
#  <span class="toctext">Dates of rank</span>,
#  <span class="toctext">Awards and honors</span>,
#  <span class="toctext">Military awards</span>,
#  <span class="toctext">Other awards</span>,
#  <span class="toctext">Legacy</span>,
#  <span class="toctext">Places</span>,
#  <span class="toctext">Programs</span>,
#  <span class="toctext">In popular culture</span>,
#  <span class="toctext">Grace Hopper Celebration of Women in Computing</span>,
#  <span class="toctext">See also</span>,
#  <span class="toctext">Notes</span>,
# ...

# %%
soup.select('.toctext')[0]
# Out:
# <span class="toctext">Early life and education</span>

# %%
type(soup.select('.toctext')[0])
# Out:
# bs4.element.Tag

# %%
first_item = soup.select('.toctext')[0]

# %%
first_item
# Out:
# <span class="toctext">Early life and education</span>

# %%
first_item.text
# Out:
# 'Early life and education'

# %%
## loop through soup and print results
for item in soup.select('.toctext'):
    print(item.text)
    
    ## this is fucking cool
# Out:
# Early life and education
# Career
# World War II
# UNIVAC
# COBOL
# Standards
# Retirement
# Post-retirement
# Anecdotes
# Death
# Dates of rank
# Awards and honors
# Military awards
# Other awards
# Legacy
# Places
# Programs
# In popular culture
# Grace Hopper Celebration of Women in Computing
# See also
# Notes
# Obituary notices
# References
# Further reading
# External links

# %% [markdown]
# ## GET IMAGES  from a website

# %%
## beautful soup can scan a page, locate <img> tags and grab the URL's of an image

## using grace hoppers's wiki again.

# %%
## grab all images with <img> tag

soup.select('img')
# Out:
# [<img alt="Commodore Grace M. Hopper, USN (covered).jpg" data-file-height="3000" data-file-width="2400" decoding="async" height="275" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ad/Commodore_Grace_M._Hopper%2C_USN_%28covered%29.jpg/220px-Commodore_Grace_M._Hopper%2C_USN_%28covered%29.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ad/Commodore_Grace_M._Hopper%2C_USN_%28covered%29.jpg/330px-Commodore_Grace_M._Hopper%2C_USN_%28covered%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ad/Commodore_Grace_M._Hopper%2C_USN_%28covered%29.jpg/440px-Commodore_Grace_M._Hopper%2C_USN_%28covered%29.jpg 2x" width="220"/>,
# ...

# %%
soup.select('img')[0] #
# Out:
# <img alt="Commodore Grace M. Hopper, USN (covered).jpg" data-file-height="3000" data-file-width="2400" decoding="async" height="275" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ad/Commodore_Grace_M._Hopper%2C_USN_%28covered%29.jpg/220px-Commodore_Grace_M._Hopper%2C_USN_%28covered%29.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ad/Commodore_Grace_M._Hopper%2C_USN_%28covered%29.jpg/330px-Commodore_Grace_M._Hopper%2C_USN_%28covered%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ad/Commodore_Grace_M._Hopper%2C_USN_%28covered%29.jpg/440px-Commodore_Grace_M._Hopper%2C_USN_%28covered%29.jpg 2x" width="220"/>

# %%
soup.select('.thumbimage')
# Out:
# [<img alt="" class="thumbimage" data-file-height="2448" data-file-width="3264" decoding="async" height="165" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Harvard_Mark_I_sign-up.agr.jpg/220px-Harvard_Mark_I_sign-up.agr.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Harvard_Mark_I_sign-up.agr.jpg/330px-Harvard_Mark_I_sign-up.agr.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Harvard_Mark_I_sign-up.agr.jpg/440px-Harvard_Mark_I_sign-up.agr.jpg 2x" width="220"/>,
# ...

# %%
image1 = soup.select('.thumbimage')[0]

# %%
image1  ## entire image tag
# Out:
# <img alt="" class="thumbimage" data-file-height="2448" data-file-width="3264" decoding="async" height="165" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Harvard_Mark_I_sign-up.agr.jpg/220px-Harvard_Mark_I_sign-up.agr.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Harvard_Mark_I_sign-up.agr.jpg/330px-Harvard_Mark_I_sign-up.agr.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Harvard_Mark_I_sign-up.agr.jpg/440px-Harvard_Mark_I_sign-up.agr.jpg 2x" width="220"/>

# %%
type(image1)
# Out:
# bs4.element.Tag

# %%
image1['src'] ## can access specific class within bs4.element.Tag object
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Harvard_Mark_I_sign-up.agr.jpg/220px-Harvard_Mark_I_sign-up.agr.jpg'

# %% [markdown]
# <img src = "//upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Harvard_Mark_I_sign-up.agr.jpg/220px-Harvard_Mark_I_sign-up.agr.jpg">

# %%
## lets download the image so we dont need it on the website
## make a specific request on that url

image1_link = requests.get("https://upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Harvard_Mark_I_sign-up.agr.jpg/220px-Harvard_Mark_I_sign-up.agr.jpg")

# %%
image1_link.content
# Out:
# b'\xff\xd8\xff\xdb\x00C\x00\x04\x03\x03\x04\x03\x03\x04\x04\x03\x04\x05\x04\x04\x05\x06\n\x07\x06\x06\x06\x06\r\t\n\x08\n\x0f\r\x10\x10\x0f\r\x0f\x0e\x11\x13\x18\x14\x11\x12\x17\x12\x0e\x0f\x15\x1c\x15\x17\x19\x19\x1b\x1b\x1b\x10\x14\x1d\x1f\x1d\x1a\x1f\x18\x1a\x1b\x1a\xff\xdb\x00C"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1d\x00\x00\x02\x01\x05\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x05\x03\x00\x01\x02\x06\x08\x07\t\xff\xc4\x00N\x10\x00\x02\x01\x02\x04\x03\x06\x01\x08\x06\x07\x06\x02\x0b\x00\x00\x01\x02\x03\x04\x11\x00\x05\x12!\x06\x131\x07\x14"AQaq\x08#2\x81\x91\xa1\xb1\xc1\x153BR\xc2\xd1\x16$%b\x82\x92\xb2\x17CSr\xa2\xe1c\xd2\x18456Ds\x83\x84\xa3\xc3\xf0\xff\xc4\x00\x1a
# ...

# %%
f = open('scraped_image.jpg', "wb") ## filename extension (.jpg) should be same as file,  MODE: write binary (wb)

# %%
f.write(image1_link.content)
# Out:
# 12110

# %%
f.close()

# %% [markdown]
# ## toscrape.com practice

# %%
## multipage website to scrape from -- a bit more realistic
